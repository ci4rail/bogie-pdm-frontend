# %%
# %matplotlib widget
# %load_ext autoreload
# %autoreload 2
# %gui asyncio

import metrics_ui.loader as mloader
import sensors_ui.loader as sloader
import datetime
import pandas as pd
from account import *


def make_filename(prefix, start_time, end_time):
    stime = start_time.strftime("%Y%m%dT%H%M%S")
    etime = end_time.strftime("%Y%m%dT%H%M%S")
    return "data/%s-%s-%s.df" % (prefix, stime, etime)

# %%
START_TIME = "2023-03-15T15:30:00+01:00"
END_TIME = "2023-03-16T15:30:00+01:00"

#TIME_RANGE = datetime.timedelta(hours=10)
start =datetime.datetime.fromisoformat(START_TIME)
end =datetime.datetime.fromisoformat(END_TIME)
#end = start + TIME_RANGE

sdf = await sloader.nats_stream_fetch( SERVER, NATS_CREDS, STREAM_NAME, EXPORT_SUBJECT_SENSORS, start, end)
sfile = make_filename("sensors", start, end)
print("loaded %d rows" % sdf.shape[0])
sdf.to_pickle(sfile)
print("saved sensors to %s" % sfile)

mdf = await mloader.nats_stream_fetch( SERVER, NATS_CREDS, STREAM_NAME, EXPORT_SUBJECT_METRICS, start, end)
mfile = make_filename("metrics", start, end)
print("loaded %d rows" % mdf.shape[0])
mdf.to_pickle(mfile)
print("saved metrics to %s" % mfile)
# Out:
# loaded 1240 rows
# nats: encountered error
# Traceback (most recent call last):
#   File "c:\python39\lib\site-packages\nats\aio\client.py", line 631, in _close
#     await self._io_writer.wait_closed()
#   File "c:\python39\lib\asyncio\streams.py", line 359, in wait_closed
#     await self._protocol._get_close_waiter(self)
#   File "c:\python39\lib\asyncio\sslproto.py", line 528, in data_received
#     ssldata, appdata = self._sslpipe.feed_ssldata(data)
#   File "c:\python39\lib\asyncio\sslproto.py", line 206, in feed_ssldata
#     self._sslobj.unwrap()
#   File "c:\python39\lib\ssl.py", line 948, in unwrap
#     return self._sslobj.shutdown()
# ssl.SSLError: [SSL: APPLICATION_DATA_AFTER_CLOSE_NOTIFY] application data after close notify (_ssl.c:2744)
# loaded 1258 rows
# loaded 1257 rows
# saved sensors to data/sensors-20230315T153000-20230316T153000.df
# loaded 25663 rows
# loaded 25663 rows
# saved metrics to data/metrics-20230315T153000-20230316T153000.df
# nats: encountered error
# Traceback (most recent call last):
#   File "c:\python39\lib\site-packages\nats\aio\client.py", line 1300, in _attempt_reconnect
#     await self._io_writer.wait_closed()
#   File "c:\python39\lib\asyncio\streams.py", line 359, in wait_closed
#     await self._protocol._get_close_waiter(self)
#   File "c:\python39\lib\site-packages\nats\aio\client.py", line 1977, in _read_loop
#     b = await self._io_reader.read(DEFAULT_BUFFER_SIZE)
#   File "c:\python39\lib\asyncio\streams.py", line 684, in read
#     await self._wait_for_data('read')
#   File "c:\python39\lib\asyncio\streams.py", line 517, in _wait_for_data
#     await self._waiter
#   File "c:\python39\lib\asyncio\selector_events.py", line 856, in _read_ready__data_received
#     data = self._sock.recv(self.max_size)
# ConnectionResetError: [WinError 10054] Eine vorhandene Verbindung wurde vom Remotehost geschlossen
# nats: encountered error
# Traceback (most recent call last):
#   File "c:\python39\lib\site-packages\nats\aio\client.py", line 1300, in _attempt_reconnect
#     await self._io_writer.wait_closed()
#   File "c:\python39\lib\asyncio\streams.py", line 359, in wait_closed
#     await self._protocol._get_close_waiter(self)
#   File "c:\python39\lib\site-packages\nats\aio\client.py", line 1977, in _read_loop
#     b = await self._io_reader.read(DEFAULT_BUFFER_SIZE)
#   File "c:\python39\lib\asyncio\streams.py", line 684, in read
#     await self._wait_for_data('read')
#   File "c:\python39\lib\asyncio\streams.py", line 517, in _wait_for_data
#     await self._waiter
#   File "c:\python39\lib\asyncio\selector_events.py", line 856, in _read_ready__data_received
#     data = self._sock.recv(self.max_size)
# ConnectionResetError: [WinError 10054] Eine vorhandene Verbindung wurde vom Remotehost geschlossen

# %%
sdf
# Out:
#                  nats_rx_time     seq                     trigger_time  \
# 0  2023-03-15 15:30:26.695162  515549 2023-03-15 15:30:26.309942+01:00
# 0  2023-03-15 15:30:47.984492  515561 2023-03-15 15:30:47.631727+01:00
# 0  2023-03-15 15:31:10.454860  515573 2023-03-15 15:31:10.077451+01:00
# 0  2023-03-15 15:31:32.920914  515585 2023-03-15 15:31:32.521767+01:00
# 0  2023-03-15 15:31:55.334764  515598 2023-03-15 15:31:54.968799+01:00
# ..                        ...     ...                              ...
# 0  2023-03-16 15:23:21.806954  559736 2023-03-16 15:22:47.595291+01:00
# 0  2023-03-16 15:23:21.866006  559747 2023-03-16 15:23:08.913066+01:00
# 0  2023-03-16 15:23:30.521641  559759 2023-03-16 15:23:30.228457+01:00
# 0  2023-03-16 15:23:56.307256  559773 2023-03-16 15:23:56.030114+01:00
# 0  2023-03-16 15:24:17.679911  559785 2023-03-16 15:24:17.343637+01:00
#
#                                           sensor_data  bogie_id  invalid  \
# 0          sensor0   sensor1   sensor2   sensor3
# 0...         1    False
# 0          sensor0   sensor1   sensor2   sensor3
# 0...         1    False
# 0          sensor0   sensor1   sensor2   sensor3
# 0...         1    False
# 0          sensor0   sensor1   sensor2   sensor3
# 0...         1    False
# 0          sensor0   sensor1   sensor2   sensor3
# 0...         1    False
# ..                                                ...       ...      ...
# 0          sensor0   sensor1   sensor2   sensor3
# 0...         1    False
# 0          sensor0   sensor1   sensor2   sensor3
# 0...         1    False
# 0          sensor0   sensor1   sensor2   sensor3
# 0...         1    False
# 0          sensor0   sensor1   sensor2   sensor3
# 0...         1    False
# 0          sensor0   sensor1   sensor2   sensor3
# 0...         1    False
#
#           lat        lon      alt   speed
# 0   49.012078  12.117272  326.421   0.008
# 0   49.012079  12.117284  327.552   0.012
# 0   49.012073  12.117281  331.342   0.015
# 0   49.012076  12.117267  334.634   0.011
# 0   49.012082  12.117256  333.528   0.059
# ..        ...        ...      ...     ...
# 0   48.767965  11.709245  359.697  33.428
# 0   48.772322  11.716113  360.252  33.379
# 0   48.776473  11.722672  359.196  33.377
# 0   48.782080  11.731527  359.491  33.378
# 0   48.786435  11.738433  357.146  33.394
#
# [1257 rows x 10 columns]
